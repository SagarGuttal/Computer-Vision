# %%
# ! pip install opencv-python

# %%
# ! pip install caer

# %% [markdown]
# ## Reading images and vedios

# %%
import cv2 as cv

# %%
# convert img into pixles ans inform of array
img = cv.imread("Images/sagar.jpg")
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [106,  93,  95],
#         [106,  93,  95],
#         [106,  93,  95]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [106,  93,  95],
#         [106,  93,  95],
#         [106,  93,  95]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [106,  93,  95],
#         [106,  93,  95],
#         [106,  93,  95]],
#
#        ...,
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [ 87, 104, 125],
#         [ 87, 104, 125],
#         [ 87, 104, 125]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [ 86, 103, 124],
#         [ 86, 103, 124],
#         [ 86, 103, 124]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [ 85, 102, 123],
#         [ 85, 102, 123],
#         [ 85, 102, 123]]], dtype=uint8)

# %%
#size of image
img.shape
# Out:
# (4000, 6000, 3)

# %%
#it opens in new windom
cv.imshow("sagar", img)
cv.waitKey(0) # Specifing window close time
# Out:
# -1

# %%
import matplotlib.pyplot as plt
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
boy_img =cv.imread("Images/Boy pic.jpg")
cv.imshow("boy", boy_img)
cv.waitKey(0)
# Out:
# -1

# %%
# read the vedio frame by frame
capture = cv.VideoCapture("Images/vedios.mp4") # Capture the vedio from system
while True:
    isTrue, frame = capture.read() # Read the img
    cv.imshow("Vedio", frame) #Show the img
    if cv.waitKey(20) & 0xFF==ord('d'): # for close the vedio
        break
capture.release() 
cv.destroyAllWindows()

# %%
# read the vedio frame by frame
capture = cv.VideoCapture(0) # Capture the vedio from webcam of system  {0 --> firstcamera 1-->secondcamera}
while True:
    isTrue, frame = capture.read() # Read the img
    cv.imshow("Vedio", frame) #Show the img
    if cv.waitKey(20) & 0xFF==ord('d'): # for close the vedio
        break
capture.release() 
cv.destroyAllWindows()

# %% [markdown]
# ## Resizing and Rescaling

# %%
#Read img
img = cv.imread("Images/sagar.jpg")
#Size of img
img.shape
# Out:
# (4000, 6000, 3)

# %%
def resize_img(img, scale):
    width = int(img.shape[1]*scale)
    height = int(img.shape[0]*scale)
    dimensions = (width,height)
    
    return cv.resize(img, dimensions, interpolation=cv.INTER_AREA)

# %%
# converted image size with scaled value like 40% size by whole 100%
rescaled_img = resize_img(img,scale=0.40)
rescaled_img.shape
# Out:
# (1600, 2400, 3)

# %%
#Read the scaled img in new window
cv.imshow("scaled img", rescaled_img)
cv.waitKey(0)
# Out:
# -1

# %%
#Read the scaled image in matplotlib
plt.imshow(cv.cvtColor(rescaled_img, cv.COLOR_BGR2RGB))
plt.axis("off") 
plt.show()

# %%
# Directly we can resize by giving dimensions
scaled_img_1 = cv.resize(rescaled_img, (250,250))
scaled_img_1.shape
# Out:
# (250, 250, 3)

# %%
# for vedios
def resize_vedio(frame, scale):
    width = int(frame.shape[1]*scale)
    height = int(frame.shape[0]*scale)
    dimensions = (width,height)
    
    return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA)

# %%
capture_1 = cv.VideoCapture("Images/vedios.mp4")
while True:
    isTrue, frame = capture_1.read()
    scaled_frame =resize_vedio(frame,scale=0.4)
    cv.imshow("Original frame", frame)
    cv.imshow("Scaled frame", scaled_frame)
    if cv.waitKey(20) and 0xFF==ord('e'):
        break
capture_1.release()
cv.destoryAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Sagar Guttal\Desktop\Data analysis(Netz)\Computer Vision\Reading_images_vedios.ipynb Cell 20 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> while True:
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     isTrue, frame = capture_1.read()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     scaled_frame =resize_vedio(frame,scale=0.4)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     cv.imshow("Original frame", frame)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a>     cv.imshow("Scaled frame", scaled_frame)
#
# c:\Users\Sagar Guttal\Desktop\Data analysis(Netz)\Computer Vision\Reading_images_vedios.ipynb Cell 20 in resize_vedio(frame, scale)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> def resize_vedio(frame, scale):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     width = int(frame.shape[1]*scale)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     height = int(frame.shape[0]*scale)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sagar%20Guttal/Desktop/Data%20analysis%28Netz%29/Computer%20Vision/Reading_images_vedios.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     dimensions = (width,height)
#
# AttributeError: 'NoneType' object has no attribute 'shape'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
